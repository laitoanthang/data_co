# %%
import sys
import time
import  config as cf 
import pandas as pd 
import pyodbc

# sys.path.append(r'C:\Users\Admin\OneDrive - VNU-HCMUS\_AI23\Sharepoint\DataCo_DWH\dataset')
sys.path.append(r'C:\Users\Admin\OneDrive - VNU-HCMUS\_AI23\Sharepoint\DataCo_On_Premises')

# read dataframe
# orders = pd.read_csv(r"C:\Users\Admin\OneDrive - VNU-HCMUS\_AI23\Sharepoint\DataCo_DWH\dataset\DataCoSupplyChainDataset.csv" , encoding='latin-1')
orders = pd.read_csv(r"C:\Users\Admin\OneDrive - VNU-HCMUS\_AI23\Sharepoint\DataCo_On_Premises\ETL Stagning\data\DataCoSupplyChainDataset.csv" , encoding='latin-1')

#change invalid datatype
orders['Product Description'] = orders['Product Description'].astype("string")
orders['Order Id'] = orders['Order Id'].astype("string")
orders['Order Customer Id'] = orders['Order Customer Id'].astype("string")
orders['Department Id'] = orders['Department Id'].astype("string")
orders['Customer Id'] = orders['Customer Id'].astype("string")
orders['Category Id'] = orders['Category Id'].astype("string")

# %%
#deal with missing value 
orders = orders.fillna({'Order Zipcode': '', 'Product Description': '' , 'Customer Zipcode' : '' , 'Customer Lname' : ''}) 
# # Check if there are any NaN values in the DataFrame
# has_nan = orders.isna().any().any()
# print(f"Are there any NaN values in 'orders'? {has_nan}")
# # Count NaN values in each column
# nan_counts = orders.isna().sum()
# print("NaN values in each column:")
# print(nan_counts)

# Set up the connection to SQL Server
server = 'localhost,1434'  # Specify the port here
database = 'DB_staging'  # Your database name
username = 'sa'  # Your username
password = 'Laitoanthang219!'  # Your password


# # Create a connection string
connection_string = f'DRIVER={{SQL Server}};SERVER={server};DATABASE={database};UID={username};PWD={password}'

# # Connect to SQL Server
conn = pyodbc.connect(connection_string)
cursor = conn.cursor()

# %%
import pandas as pd

# %%
orders = pd.read_csv("C:\\Users\\Administrator\\Desktop\\KPIM\\Internship Folder\\Dataset\\On - primises DW\\ETL Stagning\\data\\DataCoSupplyChainDataset.csv" , encoding='latin-1')

# %%
missing_rows = orders[orders.isnull().any(axis=1)]
missing_rows.isnull().sum()
# Out:
# Type                                  0
# Days for shipping (real)              0
# Days for shipment (scheduled)         0
# Benefit per order                     0
# Sales per customer                    0
# Delivery Status                       0
# Late_delivery_risk                    0
# Category Id                           0
# Category Name                         0
# Customer City                         0
# Customer Country                      0
# Customer Email                        0
# Customer Fname                        0
# Customer Id                           0
# Customer Lname                        8
# Customer Password                     0
# Customer Segment                      0
# Customer State                        0
# Customer Street                       0
# Customer Zipcode                      3
# Department Id                         0
# Department Name                       0
# Latitude                              0
# ...

# %%
# Identify rows with any missing values

missing_rows = missing_rows.fillna({'Order Zipcode': '', 'Product Description': '' , 'Customer Zipcode' : '' , 'Customer Lname' : ''}) 
missing_rows.isnull().sum()

missing_rows_1 = missing_rows[missing_rows.isnull().any(axis=1)]

# %%
missing_rows_1
# Out:
# Empty DataFrame
# Columns: [Type, Days for shipping (real), Days for shipment (scheduled), Benefit per order, Sales per customer, Delivery Status, Late_delivery_risk, Category Id, Category Name, Customer City, Customer Country, Customer Email, Customer Fname, Customer Id, Customer Lname, Customer Password, Customer Segment, Customer State, Customer Street, Customer Zipcode, Department Id, Department Name, Latitude, Longitude, Market, Order City, Order Country, Order Customer Id, order date (DateOrders), Order Id, Order Item Cardprod Id, Order Item Discount, Order Item Discount Rate, Order Item Id, Order Item Product Price, Order Item Profit Ratio, Order Item Quantity, Sales, Order Item Total, Order Profit Per Order, Order Region, Order State, Order Status, Order Zipcode, Product Card Id, Product Category Id, Product Description, Product Image, Product Name, Product Price, Product Status, shipping date (DateOrders), Shipping Mode]
# Index: []
#
# [0 rows x 53 columns]

# %%
orders = pd.read_csv(r"C:\Users\Administrator\Desktop\KPIM\Internship Folder\Dataset\On - primises DW\ETL Stagning\data\DataCoSupplyChainDataset.csv" , encoding='latin-1')

# %%
orders = orders.dropna()

# %%
orders.fillna({'Order Zipcode': '', 'Product Description': '' , 'Customer Zipcode' : ''}, inplace=True) 
orders.isnull().sum()
# Out:
# Type                             0
# Days for shipping (real)         0
# Days for shipment (scheduled)    0
# Benefit per order                0
# Sales per customer               0
# Delivery Status                  0
# Late_delivery_risk               0
# Category Id                      0
# Category Name                    0
# Customer City                    0
# Customer Country                 0
# Customer Email                   0
# Customer Fname                   0
# Customer Id                      0
# Customer Lname                   8
# Customer Password                0
# Customer Segment                 0
# Customer State                   0
# Customer Street                  0
# Customer Zipcode                 0
# Department Id                    0
# Department Name                  0
# Latitude                         0
# Longitude                        0
# Market                           0
# Order City                       0
# Order Country                    0
# ...

# %%
orders.dtypes
# Out:
# Type                              object
# Days for shipping (real)           int64
# Days for shipment (scheduled)      int64
# Benefit per order                float64
# Sales per customer               float64
# Delivery Status                   object
# Late_delivery_risk                 int64
# Category Id                        int64
# Category Name                     object
# Customer City                     object
# Customer Country                  object
# Customer Email                    object
# Customer Fname                    object
# Customer Id                        int64
# Customer Lname                    object
# Customer Password                 object
# Customer Segment                  object
# Customer State                    object
# Customer Street                   object
# Customer Zipcode                  object
# Department Id                      int64
# Department Name                   object
# Latitude                         float64
# ...

# %%
import sys
import pandas as pd
import config as cf




# Read the provided data
data = {
    'Type': 'DEBIT',
    'Days for shipping (real)': 2,
    'Days for shipment (scheduled)': 4,
    'Benefit per order': 213.690002,
    'Sales per customer': 436.100006,
    'Delivery Status': 'Advance shipping',
    'Late_delivery_risk': 0,
    'Category Id': '66',
    'Category Name': 'Crafts',
    'Customer City': 'Palatine',
    'Customer Country': 'EE. UU.',
    'Customer Email': 'XXXXXXXXX',
    'Customer Fname': 'Contreras',
    'Customer Id': '14909',
    'Customer Lname': '',
    'Customer Password': 'XXXXXXXXX',
    'Customer Segment': 'Corporate',
    'Customer State': 'IL',
    'Customer Street': '2407 Dusty Mount',
    'Customer Zipcode': '60067.0',
    'Department Id': '4',
    'Department Name': 'Apparel',
    'Latitude': 42.110535,
    'Longitude': -88.102402,
    'Market': 'Europe',
    'Order City': 'Estocolmo',
    'Order Country': 'Suecia',
    'Order Customer Id': '14909',
    'Order Date': '11/7/2017 14:50',
    'Order Id': '71356',
    'Order Item Cardprod Id': '1353',
    'Order Item Discount': 25.379999,
    'Order Item Discount Rate': 0.06,
    'Order Item Id': '174671',
    'Order Item Product Price': 461.480011,
    'Order Item Profit Ratio': 0.49,
    'Order Item Quantity': 1,
    'Sales': 461.480011,
    'Order Item Total': 436.100006,
    'Order Profit Per Order': 213.690002,
    'Order Region': 'Northern Europe',
    'Order State': 'Estocolmo',
    'Order Status': 'COMPLETE',
    'Order Zipcode': '',
    'Product Card Id': '1353',
    'Product Category Id': '66',
    'Product Description': '',
    'Product Image': 'http://images.acmesports.sports/Porcelain+crafts',
    'Product Name': 'Porcelain crafts',
    'Product Price': 461.480011,
    'Product Status': '0',
    'Shipping Date': '11/9/2017 14:50',
    'Shipping Mode': 'Standard Class'
}

# Create a DataFrame from the provided data
orders = pd.DataFrame(data, index=[0])

# Replace NaN with empty strings
orders.fillna('', inplace=True)

# Create a connection to the database
conn, cursor = cf.create_connection(server='LAPTOPNAYCUATIE', username='', password='', database='DB_staging')

# Prepare the data for insertion
data = [tuple(orders.values[0])]

# Execute the stored procedure to insert the data
try:
    cursor.executemany("EXEC sp_insert_datacoorders ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?", data)
    print("Insertion successful.")
except Exception as e:
    print("Insertion failed:", e)

# Commit and close resources
conn.commit()
cursor.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19944\481509828.py in <module>
#      70
#      71 # Create a connection to the database
# ---> 72 conn, cursor = cf.create_connection(server='LAPTOPNAYCUATIE', username='', password='', database='DB_staging')
#      73
#      74 # Prepare the data for insertion
#
# AttributeError: module 'config' has no attribute 'create_connection'

# %%
orders['Product Description'] = orders['Product Description'].astype("string")

#deal with missing value 

orders.fillna({'Order Zipcode': '', 'Product Description': ''}, inplace=True)

# %%
missing_values = orders.isna().sum()
print(missing_values)
# Out:
# Type                             0
# Days for shipping (real)         0
# Days for shipment (scheduled)    0
# Benefit per order                0
# Sales per customer               0
# Delivery Status                  0
# Late_delivery_risk               0
# Category Id                      0
# Category Name                    0
# Customer City                    0
# Customer Country                 0
# Customer Email                   0
# Customer Fname                   0
# Customer Id                      0
# Customer Lname                   8
# Customer Password                0
# Customer Segment                 0
# Customer State                   0
# Customer Street                  0
# Customer Zipcode                 3
# Department Id                    0
# Department Name                  0
# Latitude                         0
# Longitude                        0
# Market                           0
# Order City                       0
# Order Country                    0
# ...

# %%
or
