# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
# Out:
# StatementMeta(, 4e789f39-793e-4c7d-8662-aa725ab8ae46, 3, Finished, Available)

# %%
spark.sql("DROP TABLE IF EXISTS LTT_BronzeLakehouse.customer")
spark.sql("DROP TABLE IF EXISTS LTT_BronzeLakehouse.cleaned_df")
spark.sql("DROP TABLE IF EXISTS LTT_BronzeLakehouse.category")
spark.sql("DROP TABLE IF EXISTS LTT_BronzeLakehouse.customer_region")
spark.sql("DROP TABLE IF EXISTS LTT_BronzeLakehouse.delivery_risk")
spark.sql("DROP TABLE IF EXISTS LTT_BronzeLakehouse.delivery_status")
spark.sql("DROP TABLE IF EXISTS LTT_BronzeLakehouse.department")
spark.sql("DROP TABLE IF EXISTS LTT_BronzeLakehouse.desti_order")
spark.sql("DROP TABLE IF EXISTS LTT_BronzeLakehouse.order_item")
spark.sql("DROP TABLE IF EXISTS LTT_BronzeLakehouse.order_status")
spark.sql("DROP TABLE IF EXISTS LTT_BronzeLakehouse.orders")
spark.sql("DROP TABLE IF EXISTS LTT_BronzeLakehouse.product")
spark.sql("DROP TABLE IF EXISTS LTT_BronzeLakehouse.shipping")
spark.sql("DROP TABLE IF EXISTS LTT_BronzeLakehouse.transaction")
# Out:
# StatementMeta(, c130c0ea-56ce-4b48-8acf-15fbbce24cff, 3, Finished, Available)
# DataFrame[]

# %%
# tables = spark.catalog.listTables()

# for table in tables:
#     spark.sql(f"DROP TABLE IF EXISTS {table.name}")
# Out:
# StatementMeta(, 4e789f39-793e-4c7d-8662-aa725ab8ae46, 5, Finished, Available)

# %%
spark.sql("DROP TABLE IF EXISTS LTT_SilverLakehouse.category")
spark.sql("DROP TABLE IF EXISTS LTT_SilverLakehouse.customer")
spark.sql("DROP TABLE IF EXISTS LTT_SilverLakehouse.customer_region")
spark.sql("DROP TABLE IF EXISTS LTT_SilverLakehouse.department")
spark.sql("DROP TABLE IF EXISTS LTT_SilverLakehouse.destination")
spark.sql("DROP TABLE IF EXISTS LTT_SilverLakehouse.mapping_delivery_risk")
spark.sql("DROP TABLE IF EXISTS LTT_SilverLakehouse.mapping_delivery_status")
spark.sql("DROP TABLE IF EXISTS LTT_SilverLakehouse.mapping_order_status")
spark.sql("DROP TABLE IF EXISTS LTT_SilverLakehouse.mapping_shipping")
spark.sql("DROP TABLE IF EXISTS LTT_SilverLakehouse.mapping_transaction")
spark.sql("DROP TABLE IF EXISTS LTT_SilverLakehouse.delivery_risk")
spark.sql("DROP TABLE IF EXISTS LTT_SilverLakehouse.delivery_status")
spark.sql("DROP TABLE IF EXISTS LTT_SilverLakehouse.order_status")
spark.sql("DROP TABLE IF EXISTS LTT_SilverLakehouse.shipping")
spark.sql("DROP TABLE IF EXISTS LTT_SilverLakehouse.transaction")
spark.sql("DROP TABLE IF EXISTS LTT_SilverLakehouse.order_item")
spark.sql("DROP TABLE IF EXISTS LTT_SilverLakehouse.product")
spark.sql("DROP TABLE IF EXISTS LTT_SilverLakehouse.orders")
# Out:
# StatementMeta(, c130c0ea-56ce-4b48-8acf-15fbbce24cff, 4, Finished, Available)
# DataFrame[]

# %%
spark.sql("DROP TABLE IF EXISTS LTT_GoldLakehouse.dim_customer")
spark.sql("DROP TABLE IF EXISTS LTT_GoldLakehouse.dim_category")
spark.sql("DROP TABLE IF EXISTS LTT_GoldLakehouse.dim_date")
spark.sql("DROP TABLE IF EXISTS LTT_GoldLakehouse.dim_delivery_risk")
spark.sql("DROP TABLE IF EXISTS LTT_GoldLakehouse.dim_delivery_status")
spark.sql("DROP TABLE IF EXISTS LTT_GoldLakehouse.dim_department")
spark.sql("DROP TABLE IF EXISTS LTT_GoldLakehouse.dim_destination")
spark.sql("DROP TABLE IF EXISTS LTT_GoldLakehouse.dim_order_status")
spark.sql("DROP TABLE IF EXISTS LTT_GoldLakehouse.dim_product")
spark.sql("DROP TABLE IF EXISTS LTT_GoldLakehouse.dim_shipping")
spark.sql("DROP TABLE IF EXISTS LTT_GoldLakehouse.dim_store")
spark.sql("DROP TABLE IF EXISTS LTT_GoldLakehouse.dim_time")
spark.sql("DROP TABLE IF EXISTS LTT_GoldLakehouse.dim_transaction_type")
spark.sql("DROP TABLE IF EXISTS LTT_GoldLakehouse.fact_sales")
spark.sql("DROP TABLE IF EXISTS LTT_GoldLakehouse.fact_monthly_store_sales")
spark.sql("DROP TABLE IF EXISTS LTT_GoldLakehouse.fact_monthly_store_sales_plan")
spark.sql("DROP TABLE IF EXISTS LTT_GoldLakehouse.category")
spark.sql("DROP TABLE IF EXISTS LTT_GoldLakehouse.customer")
spark.sql("DROP TABLE IF EXISTS LTT_GoldLakehouse.department")
spark.sql("DROP TABLE IF EXISTS LTT_GoldLakehouse.product")
# Out:
# StatementMeta(, 4e789f39-793e-4c7d-8662-aa725ab8ae46, 9, Finished, Available)
# DataFrame[]
